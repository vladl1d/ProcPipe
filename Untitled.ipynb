# %%
import sys
from matplotlib import pyplot as plt
import numpy as np
sys.path.append(r'C:\Users\v-liderman\DataAdapter')
from datetime import datetime, timedelta
from Util import get_typed_value


tdata, i = np.loadtxt(r'C:\Users\v-liderman\Desktop\out.json', delimiter='\t', dtype=object, \
                      converters={0: lambda x: get_typed_value(x, datetime),\
                                  1: lambda x: get_typed_value(x, int)}, unpack=True)

# %%
#print(data[:100])
tdata1 = tdata[::1000]
i1 = i[::1000]

# %%
    from matplotlib import pyplot as plt
    #вычиялем разницу
    max_i = tdata1.shape[0]
    new_data = np.zeros(max_i - 1)
    for idx in range(max_i):
        if idx < max_i - 1:
            new_data[idx] = (tdata1[idx+1] - tdata1[idx]).microseconds

# %%
print(i1.shape, new_data.shape)
# Out:
# (85,) (85,)

# %%
    i1 = (i1/1000)[:-1]

# %%
    plt.figure(1)
    plt.plot(i1, new_data)
    plt.figure(2)
    plt.hist(new_data)
    plt.show()

# %%
new_data
# Out:
# array([133955., 952576., 873473., 866471.,  37989.,  94033., 897687.,
#        313504.,  94278., 821980., 890379., 946055., 425367., 751922.,
#        969438., 556928., 698186., 369049., 963342.,  88705., 280080.,
#        891507., 536897.,  19920., 957606., 805855., 163331., 237610.,
#        846734., 622722.,  32413., 911637., 881499.,  71521., 767020.,
#        671053., 522083., 400654., 378003., 433611., 948973.,  97727.,
#         21575., 896234., 106501., 734805., 732842., 709440., 765412.,
#        997943., 757830., 770383., 815286., 693378., 719873., 809441.,
#        731410., 764401., 743275., 752726., 813471., 709824., 706391.,
#        338853., 712388., 725116., 723877., 706343.,  23950., 790771.,
#        739305., 728396., 971294., 649881., 454633., 907849., 717069.,
#        727360., 706397., 699298., 875428.,  61837., 925438., 875447.,
#        992754.])

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading https://files.pythonhosted.org/packages/43/a2/78344d1fdd5a722bea5144b07da3f9caf4cd7adf645d17bb389cd135ef0d/psycopg2-2.7.6.1-cp35-cp35m-win_amd64.whl (996kB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.7.6.1
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import psycorg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-63bc360f4e02> in <module>()
# ----> 1 import psycorg
#
# ImportError: No module named 'psycorg'
